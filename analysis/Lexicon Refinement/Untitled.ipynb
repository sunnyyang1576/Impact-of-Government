# %%
import pandas as pd 
import numpy as np

# %%
data_directory = "data/output/"

# %%
file = "index_economy_refinement_cwhy_m.csv"

# %%
df = pd.read_csv(data_directory+file)

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df = df.set_index("date")

# %%
df.plot()
