# %%
import requests

# %%
headers = {
'X-Requested-With': 'XMLHttpRequest',
'User-Agent':' Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36',
}

# %%
query = {'pageNum': 1,
'pageSize': 30,
'column': 'szse',
'tabName': 'fulltext',
'plate': '',
'stock': '',
'searchkey':'' ,
'secid':'' ,
'category':'' ,
'trade': '',
'seDate': '2020-03-07~2020-09-07',
'sortName':'' ,
'sortType':'',
'isHLtitle': True}

# %%
URL = 'http://www.cninfo.com.cn/new/hisAnnouncement/query'

# %%
response = requests.post(URL, query, HEADER, timeout=10)

# %%
response.json()
# Out:
# {'classifiedAnnouncements': None,
#  'totalSecurities': 0,
#  'totalAnnouncement': 341561,
#  'totalRecordNum': 341561,
#  'announcements': [{'id': None,
#    'secCode': '002305',
#    'secName': '南国置业',
#    'orgId': '9900008690',
#    'announcementId': '1208403930',
#    'announcementTitle': '关于召开公司2020年第三次临时股东大会的通知',
#    'announcementTime': 1599450420000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403930.PDF',
#    'adjunctSize': 317,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '01010302||01010411||09020202||250201||251302',
#    'pageColumn': 'SZZX',
#    'announcementType': '01010503||010112||010114||01190110',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '002305',
#    'secName': '南国置业',
#    'orgId': '9900008690',
#    'announcementId': '1208403928',
#    'announcementTitle': '吸收合并中国电建地产集团有限公司暨关联交易报告书（草案）（修订稿）',
#    'announcementTime': 1599450420000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403928.PDF',
#    'adjunctSize': 5734,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '01010302||01010411||09020202||250201||251302',
#    'pageColumn': 'SZZX',
#    'announcementType': '01010503||010112||010114||011719',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '002305',
#    'secName': '南国置业',
#    'orgId': '9900008690',
#    'announcementId': '1208403927',
#    'announcementTitle': '独立董事关于第五届董事会第六次临时会议相关事项的事前认可意见',
#    'announcementTime': 1599450420000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403927.PDF',
#    'adjunctSize': 60,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '01010302||01010310||01010411||09020202||250201||251302',
#    'pageColumn': 'SZZX',
#    'announcementType': '01011107||010112||010114||01310565',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '002305',
#    'secName': '南国置业',
#    'orgId': '9900008690',
#    'announcementId': '1208403926',
#    'announcementTitle': '独立董事关于第五届董事会第六次临时会议相关事项的独立意见',
#    'announcementTime': 1599450420000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403926.PDF',
#    'adjunctSize': 59,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '01010302||01010310||01010411||09020202||250201||251302',
#    'pageColumn': 'SZZX',
#    'announcementType': '01011107||010112||010114||01310565',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '002305',
#    'secName': '南国置业',
#    'orgId': '9900008690',
#    'announcementId': '1208403925',
#    'announcementTitle': '第五届监事会第五次临时会议决议公告',
#    'announcementTime': 1599450420000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403925.PDF',
#    'adjunctSize': 213,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '01010302||01010411||09020202||250201||251302',
#    'pageColumn': 'SZZX',
#    'announcementType': '01010505||010112||010114||01239910',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '002305',
#    'secName': '南国置业',
#    'orgId': '9900008690',
#    'announcementId': '1208403924',
#    'announcementTitle': '关于公司本次吸收合并中国电建地产集团有限公司并募集配套资金暨关联交易取消募集配套资金的公告',
#    'announcementTime': 1599450420000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403924.PDF',
#    'adjunctSize': 220,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '01010302||01010411||09020202||250201||251302',
#    'pageColumn': 'SZZX',
#    'announcementType': '01010503||010112||010114||011511||011719',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '002305',
#    'secName': '南国置业',
#    'orgId': '9900008690',
#    'announcementId': '1208403923',
#    'announcementTitle': '第五届董事会第六次临时会议决议公告',
#    'announcementTime': 1599450419000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403923.PDF',
#    'adjunctSize': 217,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '01010302||01010411||09020202||250201||251302',
#    'pageColumn': 'SZZX',
#    'announcementType': '01010503||010112||010114||01239901',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '300861',
#    'secName': '美畅股份',
#    'orgId': 'gfbj0872859',
#    'announcementId': '1208403937',
#    'announcementTitle': '关于首次公开发行股票募投项目之高效金刚石线建设项目实施进展情况的公告',
#    'announcementTime': 1599450381000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403937.PDF',
#    'adjunctSize': 108,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '09020202||160203||250301||251302',
#    'pageColumn': 'SZCY',
#    'announcementType': '01010503||010112||010115||01231501',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '002614',
#    'secName': '奥佳华',
#    'orgId': '9900021412',
#    'announcementId': '1208403936',
#    'announcementTitle': '简式权益变动报告书',
#    'announcementTime': 1599450378000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403936.PDF',
#    'adjunctSize': 470,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '01010302||01010411||09020202||250201||251302',
#    'pageColumn': 'SZZX',
#    'announcementType': '01011101||010112||010114||01150110',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '002614',
#    'secName': '奥佳华',
#    'orgId': '9900021412',
#    'announcementId': '1208403935',
#    'announcementTitle': '关于公司控股股东及其一致行动人持股比例被动稀释超过1%的公告',
#    'announcementTime': 1599450378000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403935.PDF',
#    'adjunctSize': 335,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '01010302||01010411||09020202||250201||251302',
#    'pageColumn': 'SZZX',
#    'announcementType': '01010503||010112||010114||01150101',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '002614',
#    'secName': '奥佳华',
#    'orgId': '9900021412',
#    'announcementId': '1208403934',
#    'announcementTitle': '关于公司5%以上股东被动稀释降至5%以下的提示性公告',
#    'announcementTime': 1599450378000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403934.PDF',
#    'adjunctSize': 277,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '01010302||01010411||09020202||250201||251302',
#    'pageColumn': 'SZZX',
#    'announcementType': '01010503||010112||010114||01150101',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '300037',
#    'secName': '新宙邦',
#    'orgId': '9900009195',
#    'announcementId': '1208403933',
#    'announcementTitle': '关于部分董事、监事、高级管理人员股份减持计划时间过半的公告',
#    'announcementTime': 1599450374000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403933.PDF',
#    'adjunctSize': 184,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '09020202||160203||250301||251302',
#    'pageColumn': 'SZCY',
#    'announcementType': '01010503||010112||010115||01230350',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '002937',
#    'secName': '兴瑞科技',
#    'orgId': '9900035540',
#    'announcementId': '1208403932',
#    'announcementTitle': '关于使用部分闲置募集资金进行现金管理到期赎回的更正公告',
#    'announcementTime': 1599450371000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403932.PDF',
#    'adjunctSize': 198,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '01010302||01010411||09020202||250201||251302',
#    'pageColumn': 'SZZX',
#    'announcementType': '01010503||010112||010114||01231510||01270310',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '300195',
#    'secName': '长荣股份',
#    'orgId': '9900017111',
#    'announcementId': '1208403931',
#    'announcementTitle': '关于控股股东、实际控制人及其一致行动人部分股份解除质押的公告',
#    'announcementTime': 1599450368000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403931.PDF',
#    'adjunctSize': 85,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '09020202||160203||250301||251302',
#    'pageColumn': 'SZCY',
#    'announcementType': '01010503||010112||010115||01230720',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '300218',
#    'secName': '安利股份',
#    'orgId': '9900019028',
#    'announcementId': '1208403929',
#    'announcementTitle': '关于召开2020年第一次临时股东大会的提示性公告',
#    'announcementTime': 1599450365000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403929.PDF',
#    'adjunctSize': 213,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '09020202||160203||250301||251302',
#    'pageColumn': 'SZCY',
#    'announcementType': '01010503||010112||010115||01190110',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '300395',
#    'secName': '菲利华',
#    'orgId': '9900023110',
#    'announcementId': '1208403922',
#    'announcementTitle': '使用暂时闲置的自有资金进行现金管理的进展公告',
#    'announcementTime': 1599450362000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403922.PDF',
#    'adjunctSize': 64,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '09020202||160203||250301||251302',
#    'pageColumn': 'SZCY',
#    'announcementType': '01010503||010112||010115||01170520',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '300864',
#    'secName': '南大环境',
#    'orgId': '9900041610',
#    'announcementId': '1208403921',
#    'announcementTitle': '关于取消2020年第三次临时股东大会的公告',
#    'announcementTime': 1599450359000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403921.PDF',
#    'adjunctSize': 248,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '09020202||160203||250301||251302',
#    'pageColumn': 'SZCY',
#    'announcementType': '01010503||010112||010115||01190340',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '300864',
#    'secName': '南大环境',
#    'orgId': '9900041610',
#    'announcementId': '1208403920',
#    'announcementTitle': '关于第二届董事会第七次会议决议的公告',
#    'announcementTime': 1599450359000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403920.PDF',
#    'adjunctSize': 285,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '09020202||160203||250301||251302',
#    'pageColumn': 'SZCY',
#    'announcementType': '01010503||010112||010115||01239901',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '300806',
#    'secName': '斯迪克',
#    'orgId': '9900024958',
#    'announcementId': '1208403911',
#    'announcementTitle': '平安证券股份有限公司关于公司2020半年度跟踪报告',
#    'announcementTime': 1599450359000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403911.PDF',
#    'adjunctSize': 153,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '09020202||160203||160219||250301||250309||251302',
#    'pageColumn': 'SZCY',
#    'announcementType': '01010701||010112||010115||012917',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '300739',
#    'secName': '明阳电路',
#    'orgId': '9900035314',
#    'announcementId': '1208403919',
#    'announcementTitle': '关于公司公开发行可转换公司债券申请文件反馈意见的回复（修订稿）的公告',
#    'announcementTime': 1599450355000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403919.PDF',
#    'adjunctSize': 103,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '09020202||160201||160203||250301||251302||2705',
#    'pageColumn': 'SZCY',
#    'announcementType': '01010503||010112||010115||01099999',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '300739',
#    'secName': '明阳电路',
#    'orgId': '9900035314',
#    'announcementId': '1208403918',
#    'announcementTitle': '公司、民生证券股份有限公司关于公司公开发行可转换公司债券申请文件反馈意见的回复（修订稿）',
#    'announcementTime': 1599450355000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403918.PDF',
#    'adjunctSize': 1445,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '09020202||160203||250301||251302',
#    'pageColumn': 'SZCY',
#    'announcementType': '01010701||010112||010115||0129',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '300852',
#    'secName': '四会富仕',
#    'orgId': '9900039723',
#    'announcementId': '1208403917',
#    'announcementTitle': '民生证券股份有限公司关于公司变更部分募集资金专户事项的核查意见',
#    'announcementTime': 1599450352000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403917.PDF',
#    'adjunctSize': 210,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '09020202||160203||250301||251302',
#    'pageColumn': 'SZCY',
#    'announcementType': '01010701||010112||010115||0129',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '300852',
#    'secName': '四会富仕',
#    'orgId': '9900039723',
#    'announcementId': '1208403916',
#    'announcementTitle': '独立董事对第一届董事会第十六次会议相关事项的独立意见',
#    'announcementTime': 1599450352000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403916.PDF',
#    'adjunctSize': 64,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '09020202||160203||160210||250301||251302',
#    'pageColumn': 'SZCY',
#    'announcementType': '01011107||010112||010115||01310565',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '300852',
#    'secName': '四会富仕',
#    'orgId': '9900039723',
#    'announcementId': '1208403915',
#    'announcementTitle': '第一届监事会第十五次会议决议公告',
#    'announcementTime': 1599450352000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403915.PDF',
#    'adjunctSize': 75,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '09020202||160203||250301||251302',
#    'pageColumn': 'SZCY',
#    'announcementType': '01010505||010112||010115||01239910',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '300852',
#    'secName': '四会富仕',
#    'orgId': '9900039723',
#    'announcementId': '1208403914',
#    'announcementTitle': '关于变更部分募集资金专用账户并签订三方监管协议之补充协议的公告',
#    'announcementTime': 1599450352000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403914.PDF',
#    'adjunctSize': 83,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '09020202||160203||250301||251302',
#    'pageColumn': 'SZCY',
#    'announcementType': '01010503||010112||010115||01231550',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '300852',
#    'secName': '四会富仕',
#    'orgId': '9900039723',
#    'announcementId': '1208403913',
#    'announcementTitle': '第一届董事会第十六次会议决议公告',
#    'announcementTime': 1599450351000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403913.PDF',
#    'adjunctSize': 79,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '09020202||160203||250301||251302',
#    'pageColumn': 'SZCY',
#    'announcementType': '01010503||010112||010115||01239901',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '300137',
#    'secName': '先河环保',
#    'orgId': '9900014612',
#    'announcementId': '1208403912',
#    'announcementTitle': '关于公司通过CMMI5级评估认证的公告',
#    'announcementTime': 1599450345000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403912.PDF',
#    'adjunctSize': 89,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '09020202||160203||250301||251302',
#    'pageColumn': 'SZCY',
#    'announcementType': '01010503||010112||010115||01230520',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '000932',
#    'secName': '华菱钢铁',
#    'orgId': 'gssz0000932',
#    'announcementId': '1208403902',
#    'announcementTitle': '《关于请做好湖南华菱钢铁股份有限公司可转债申请发审委会议准备工作的函》相关问题的回复（修订稿）',
#    'announcementTime': 1599450339000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403902.PDF',
#    'adjunctSize': 1242,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '09020202||250101||251302||2705',
#    'pageColumn': 'SZZB',
#    'announcementType': '01010501||010112||010999',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '000932',
#    'secName': '华菱钢铁',
#    'orgId': 'gssz0000932',
#    'announcementId': '1208403901',
#    'announcementTitle': '关于可转债发行告知函相关问题回复修订稿的公告',
#    'announcementTime': 1599450339000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403901.PDF',
#    'adjunctSize': 126,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '09020202||250101||251302||2705',
#    'pageColumn': 'SZZB',
#    'announcementType': '01010501||010112||01099999',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None},
#   {'id': None,
#    'secCode': '300642',
#    'secName': '透景生命',
#    'orgId': '9900031825',
#    'announcementId': '1208403910',
#    'announcementTitle': '关于召开公司2020年第一次临时股东大会的提示性公告',
#    'announcementTime': 1599450338000,
#    'adjunctUrl': 'finalpage/2020-09-07/1208403910.PDF',
#    'adjunctSize': 199,
#    'adjunctType': 'PDF',
#    'storageTime': None,
#    'columnId': '09020202||160203||250301||251302',
#    'pageColumn': 'SZCY',
#    'announcementType': '01010503||010112||010115||01190110',
#    'associateAnnouncement': None,
#    'important': None,
#    'batchNum': None,
#    'announcementContent': '',
#    'orgName': None,
#    'announcementTypeName': None}],
#  'categoryList': None,
#  'hasMore': True,
#  'totalpages': 11385}
