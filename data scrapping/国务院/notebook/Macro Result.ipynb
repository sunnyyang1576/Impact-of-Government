# %%
import pandas as pd
import numpy as np
from scipy.stats import pearsonr

# %%
from statsmodels.tsa.api import VAR

# %%
def calculate_correlation_df(agg_df):
    
    corr_df = agg_df.corr()
    corr_df = corr_df.round(3)
    
    rho = corr_df
    pval = agg_df.corr(method=lambda x, y: pearsonr(x, y)[1]) - np.eye(*rho.shape)
    p = pval.applymap(lambda x: ''.join(['*' for t in [0.01,0.05,0.1] if x<=t]))
    corr_p_df = rho.astype(str) + p
    return corr_p_df

# %%
data_directory = "data/output/"
file = "monthly_score_df.csv"

# %%
df = pd.read_csv(data_directory+file)

# %%
df["date"] = pd.to_datetime(df.date)
df = df.set_index("date")

# %%
index_df = df

# %%
file_2 = "weekly_score_df.csv"
file_3 = "daily_score_df.csv"

# %%
w_df = pd.read_csv(data_directory+file_2)
d_df = pd.read_csv(data_directory+file_3)

# %%
w_df["date"] = pd.to_datetime(w_df["date"])
d_df["date"] = pd.to_datetime(d_df["date"])

# %%
w_df = w_df.set_index("date")
d_df = d_df.set_index("date")

# %%
def year(x):
    
    return x.year

def month(x):
    
    return x.month

year_series = pd.Series(w_df.index).apply(year)
month_series = pd.Series(w_df.index).apply(month)

# %%
w_df["year"] = list(year_series)
w_df["month"] = list(month_series)

# %%
w_m_df = w_df.groupby(["year","month"]).mean()

# %%
def year(x):
    
    return x.year

def month(x):
    
    return x.month

year_series = pd.Series(d_df.index).apply(year)
month_series = pd.Series(d_df.index).apply(month)

# %%
d_df["year"] = list(year_series)
d_df["month"] = list(month_series)

# %%
d_m_df = w_df.groupby(["year","month"]).mean()

# %%
w_m_df.index = df.index
d_m_df.index = df.index

# %%
w_m_df.columns = ["w_"+col for col in w_m_df.columns]
d_m_df.columns = ["d_"+col for col in d_m_df.columns]

# %%
merge_df = df.merge(w_m_df,left_index=True,right_index=True)
merge_df = merge_df.merge(d_m_df,left_index=True,right_index=True)

# %%
calculate_correlation_df(merge_df)
# Out:
#                  economy    reform regulation intervention w_economy  \
# economy           1.0***  0.466***     -0.025        0.021  0.849***
# reform          0.466***    1.0***   0.476***         0.13  0.372***
# regulation        -0.025  0.476***     1.0***     0.392***    -0.041
# intervention       0.021      0.13   0.392***       1.0***    -0.012
# w_economy       0.849***  0.372***     -0.041       -0.012    1.0***
# w_reform        0.479***  0.886***   0.371***        0.051  0.403***
# w_regulation       0.075  0.388***    0.76***      0.309**    -0.002
# w_intervention      -0.0     0.168    0.37***     0.806***     -0.01
# d_economy       0.849***  0.372***     -0.041       -0.012    1.0***
# d_reform        0.479***  0.886***   0.371***        0.051  0.403***
# d_regulation       0.075  0.388***    0.76***      0.309**    -0.002
# d_intervention      -0.0     0.168    0.37***     0.806***     -0.01
#
#                 w_reform w_regulation w_intervention d_economy  d_reform  \
# economy         0.479***        0.075           -0.0  0.849***  0.479***
# reform          0.886***     0.388***          0.168  0.372***  0.886***
# regulation      0.371***      0.76***        0.37***    -0.041  0.371***
# intervention       0.051      0.309**       0.806***    -0.012     0.051
# w_economy       0.403***       -0.002          -0.01    1.0***  0.403***
# w_reform          1.0***     0.443***          0.118  0.403***    1.0***
# w_regulation    0.443***       1.0***         0.257*    -0.002  0.443***
# w_intervention     0.118       0.257*         1.0***     -0.01     0.118
# d_economy       0.403***       -0.002          -0.01    1.0***  0.403***
# d_reform          1.0***     0.443***          0.118  0.403***    1.0***
# d_regulation    0.443***       1.0***         0.257*    -0.002  0.443***
# d_intervention     0.118       0.257*         1.0***     -0.01     0.118
#
#                d_regulation d_intervention
# economy               0.075           -0.0
# reform             0.388***          0.168
# regulation          0.76***        0.37***
# intervention        0.309**       0.806***
# w_economy            -0.002          -0.01
# w_reform           0.443***          0.118
# w_regulation         1.0***         0.257*
# w_intervention       0.257*         1.0***
# d_economy            -0.002          -0.01
# d_reform           0.443***          0.118
# d_regulation         1.0***         0.257*
# d_intervention       0.257*         1.0***

# %%
macro_directory = "data/macro_after_clean/"
macro_file_1 = "ppi_yoy.xls"
macro_file_2 = "m2_chain.xls"
macro_file_3 = "cpi_yoy.xls"
macro_file_4 = "money_multiplier.xls"
macro_file_5 = "new_employment.xls"
macro_file_6 = "pmi.xls"

# %%
series_list = []

# %%
macro_1 = pd.read_excel(macro_directory+macro_file_6)

# %%
macro_1["date"] = pd.to_datetime(macro_1["date"])
macro_1 = macro_1.set_index("date")

# %%
macro_1 = macro_1.iloc[:,0:1]

# %%
macro_1
# Out:
#             PMI
# date
# 2005-01-31  4.7
# 2005-02-28  4.5
# 2005-03-31  7.9
# 2005-04-30  6.7
# 2005-05-31  2.9
# ...         ...
# 2020-06-30  0.9
# 2020-07-31  1.1
# 2020-08-31  1.0
# 2020-09-30  1.5
# 2020-10-31  1.4
#
# [190 rows x 1 columns]

# %%
series_list.append(macro_1)

# %%
macro_df = pd.concat(series_list,axis=1)

# %%
macro_df = macro_df.dropna()

# %%
merge_df = df.merge(macro_df,left_index=True,right_index=True)

# %%
merge_df
# Out:
#              economy    reform  regulation  intervention  PPI        M2  \
# date
# 2016-05-31  0.777191  2.393915    0.415610      0.315864 -2.8  0.011407
# 2016-06-30  1.340982  2.262460    0.286841      0.358551 -2.6  0.019701
# 2016-08-31  0.272351  0.976909    0.272351      0.224985 -0.8  0.013023
# 2016-09-30  0.573587  0.868930    0.181869      0.236274  0.1  0.003559
# 2016-10-31  0.595705  1.405436    0.199757      0.253264  1.2  0.002061
# 2016-11-30  0.548715  1.224732    0.272163      0.300696  3.3  0.007204
# 2017-01-31  0.387150  1.221010    0.327588      0.148904  6.9  0.022017
# 2017-02-28  0.269962  1.033122    0.638563      0.181705  7.8  0.003574
# 2017-03-31  0.501263  1.093306    0.209189      0.196032  7.6  0.011373
# 2017-05-31  0.463494  1.031647    0.269125      0.398704  5.5  0.003630
# 2020-04-30           125.0  0.8
# 2020-06-30           104.0  0.9
# 2020-07-31           107.0  1.1
# 2020-08-31           110.0  1.0
# 2020-09-30           117.0  1.5

# %%
merge_df.corr().round(2)
# Out:
#                    economy  reform  regulation  intervention   PPI    M2  \
# economy               1.00    0.55        0.05          0.10 -0.31  0.26
# reform                0.55    1.00        0.45          0.18 -0.14 -0.08
# regulation            0.05    0.45        1.00          0.52 -0.04 -0.01
# intervention          0.10    0.18        0.52          1.00 -0.49 -0.04
# PPI                  -0.31   -0.14       -0.04         -0.49  1.00 -0.09
# M2                    0.26   -0.08       -0.01         -0.04 -0.09  1.00
# CPI_yoy              -0.13   -0.03        0.04          0.40 -0.47  0.14
# m_multiplier          0.05   -0.04        0.21          0.62 -0.65 -0.11
# m_multiplier_yoy      0.21    0.20       -0.00          0.11 -0.69 -0.08
# m_multiplier_diff    -0.17   -0.21       -0.14         -0.06  0.10 -0.11
# new_empolyment        0.30    0.12       -0.08          0.07 -0.01 -0.15
# PMI                  -0.06   -0.31       -0.03         -0.26  0.54  0.13
#
#                    CPI_yoy  m_multiplier  m_multiplier_yoy  m_multiplier_diff  \
# economy              -0.13          0.05              0.21              -0.17
# reform               -0.03         -0.04              0.20              -0.21
# regulation            0.04          0.21             -0.00              -0.14
# intervention          0.40          0.62              0.11              -0.06
# PPI                  -0.47         -0.65             -0.69               0.10
# M2                    0.14         -0.11             -0.08              -0.11
# CPI_yoy               1.00          0.51              0.15              -0.10
# m_multiplier          0.51          1.00              0.45               0.09
# m_multiplier_yoy      0.15          0.45              1.00               0.13
# m_multiplier_diff    -0.10          0.09              0.13               1.00
# new_empolyment       -0.32         -0.04              0.04               0.07
# PMI                  -0.31         -0.23             -0.56               0.02
#
#                    new_empolyment   PMI
# economy                      0.30 -0.06
# reform                       0.12 -0.31
# regulation                  -0.08 -0.03
# intervention                 0.07 -0.26
# PPI                         -0.01  0.54
# M2                          -0.15  0.13
# CPI_yoy                     -0.32 -0.31
# m_multiplier                -0.04 -0.23
# m_multiplier_yoy             0.04 -0.56
# m_multiplier_diff            0.07  0.02
# new_empolyment               1.00  0.24
# PMI                          0.24  1.00

# %%
calculate_correlation_df(merge_df)
# Out:
#                     economy    reform regulation intervention        PPI  \
# economy              1.0***  0.552***      0.055          0.1    -0.314*
# reform             0.552***    1.0***   0.451***        0.182     -0.136
# regulation            0.055  0.451***     1.0***     0.516***     -0.041
# intervention            0.1     0.182   0.516***       1.0***  -0.489***
# PPI                 -0.314*    -0.136     -0.041    -0.489***     1.0***
# M2                    0.259    -0.079     -0.006       -0.044     -0.093
# CPI_yoy              -0.127    -0.033      0.044      0.397**   -0.47***
# m_multiplier          0.053     -0.04      0.212     0.625***  -0.646***
# m_multiplier_yoy      0.214     0.205     -0.004        0.114  -0.695***
# m_multiplier_diff    -0.172     -0.21     -0.143       -0.061      0.095
# new_empolyment       0.301*     0.121     -0.076        0.068     -0.006
# PMI                  -0.058   -0.309*     -0.028       -0.257   0.538***
#
#                        M2   CPI_yoy m_multiplier m_multiplier_yoy  \
# economy             0.259    -0.127        0.053            0.214
# reform             -0.079    -0.033        -0.04            0.205
# regulation         -0.006     0.044        0.212           -0.004
# intervention       -0.044   0.397**     0.625***            0.114
# PPI                -0.093  -0.47***    -0.646***        -0.695***
# M2                 1.0***     0.136       -0.114           -0.079
# CPI_yoy             0.136    1.0***     0.508***            0.147
# m_multiplier       -0.114  0.508***       1.0***         0.449***
# m_multiplier_yoy   -0.079     0.147     0.449***           1.0***
# m_multiplier_diff   -0.11    -0.102        0.093            0.132
# new_empolyment     -0.148   -0.316*       -0.036             0.04
# PMI                 0.126   -0.305*       -0.231        -0.563***
#
#                   m_multiplier_diff new_empolyment        PMI
# economy                      -0.172         0.301*     -0.058
# reform                        -0.21          0.121    -0.309*
# regulation                   -0.143         -0.076     -0.028
# intervention                 -0.061          0.068     -0.257
# PPI                           0.095         -0.006   0.538***
# M2                            -0.11         -0.148      0.126
# CPI_yoy                      -0.102        -0.316*    -0.305*
# m_multiplier                  0.093         -0.036     -0.231
# m_multiplier_yoy              0.132           0.04  -0.563***
# m_multiplier_diff            1.0***          0.074      0.023
# new_empolyment                0.074         1.0***      0.244
# PMI                           0.023          0.244     1.0***

# %%
columns = ["intervention","PPI","M2","CPI_yoy","m_multiplier","new_empolyment","PMI"]
columns = ["intervention","PMI"]

# %%
var_df = merge_df[columns]

# %%
model = VAR(var_df)
# Out:
# /Users/sunnyyang/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
results = model.fit(3)

# %%
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 19, Nov, 2020
# Time:                     20:49:49
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -3.50030
# Nobs:                     36.0000    HQIC:                  -3.90118
# Log likelihood:          -14.0736    FPE:                  0.0164722
# AIC:                     -4.11611    Det(Omega_mle):       0.0115457
# --------------------------------------------------------------------
# Results for equation intervention
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.182608         0.112308            1.626           0.104
# L1.intervention         0.357177         0.170273            2.098           0.036
# L1.PMI                 -0.005766         0.050311           -0.115           0.909
# L2.intervention        -0.147276         0.181182           -0.813           0.416
# L2.PMI                 -0.030041         0.054197           -0.554           0.579
# L3.intervention         0.414175         0.184452            2.245           0.025
# L3.PMI                  0.015765         0.049785            0.317           0.752
# ==================================================================================
#
# Results for equation PMI
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.315885         0.421331            0.750           0.453
# L1.intervention        -0.108272         0.638794           -0.169           0.865
# L1.PMI                  0.535193         0.188746            2.836           0.005
# L2.intervention         0.010632         0.679719            0.016           0.988
# L2.PMI                  0.342858         0.203323            1.686           0.092
# L3.intervention        -0.138154         0.691987           -0.200           0.842
# L3.PMI                 -0.121639         0.186772           -0.651           0.515
# ==================================================================================
#
# Correlation matrix of residuals
#                 intervention       PMI
# intervention        1.000000 -0.148424
# PMI                -0.148424  1.000000
